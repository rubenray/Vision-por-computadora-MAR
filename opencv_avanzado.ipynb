# %% [markdown]
# <a href="https://colab.research.google.com/github/rubenray/Vision-por-computadora-MAR/blob/main/opencv_avanzado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📸🔍 Notebook Avanzado de OpenCV
# Incluye:
# - Detección Facial (Haar Cascades)
# - Filtros avanzados
# - Segmentación por color y thresholding
# - Captura desde webcam en Colab
# - Tracking de objetos (color)

# %% [markdown]
# ## 1️⃣ Instalar OpenCV

# %%
# !pip install opencv-python-headless

# %% [markdown]
# ## 2️⃣ Importar Librerías

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files

# %% [markdown]
# ## 3️⃣ Detección Facial con Haar Cascades

# %%
uploaded = files.upload()  # Subir imagen
img = cv2.imread(list(uploaded.keys())[0])

# Convertir a gris
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Cargar Haar Cascade de OpenCV
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# Detectar rostros
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# Dibujar rectángulos
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0,255,0), 2)

cv2_imshow(img)
# Out:
#      <input type="file" id="files-c2a938a2-f93a-4a34-93c0-22aa09eaab86" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2a938a2-f93a-4a34-93c0-22aa09eaab86">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 4️⃣ Filtros avanzados

# %%
uploaded = files.upload()
img = cv2.imread(list(uploaded.keys())[0])

# Blur
blur = cv2.blur(img, (10,10))

# Gaussian Blur
gauss = cv2.GaussianBlur(img, (11,11), 0)

# Sharpen
kernel_sharp = np.array([[0,-1,0], [-1,5,-1], [0,-1,0]])
sharp = cv2.filter2D(img, -1, kernel_sharp)

print('Blur:')
cv2_imshow(blur)
print('Gaussian:')
cv2_imshow(gauss)
print('Sharpen:')
cv2_imshow(sharp)

# %% [markdown]
# ## 5️⃣ Segmentación: Thresholding y Segmentación por Color (HSV)

# %%
uploaded = files.upload()
img = cv2.imread(list(uploaded.keys())[0])
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Segmentación por color (detectar rojo)
lower_red = np.array([0,120,70])
upper_red = np.array([10,255,255])
mask1 = cv2.inRange(hsv, lower_red, upper_red)

# Segundo rango del rojo
lower_red2 = np.array([170,120,70])
upper_red2 = np.array([180,255,255])
mask2 = cv2.inRange(hsv, lower_red2, upper_red2)

mask = mask1 + mask2
result = cv2.bitwise_and(img, img, mask=mask)

cv2_imshow(mask)
cv2_imshow(result)

# %% [markdown]
# ## 6️⃣ Captura de Webcam en Google Colab

# %%
from IPython.display import display, Javascript

def capture_image():
    js = Javascript('''
    async function takePhoto() {
        const div = document.createElement('div');
        const video = document.createElement('video');
        div.appendChild(video);
        document.body.appendChild(div);

        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        video.srcObject = stream;
        await video.play();

        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);

        stream.getVideoTracks()[0].stop();
        div.remove();

        return canvas.toDataURL('image/png');
    }
    ''')

    display(js)
    data = eval_js('takePhoto()')
    return data

from google.colab import output
data = capture_image()

# Convertir a imagen
import base64
import cv2
import numpy as np

img_bytes = base64.b64decode(data.split(',')[1])
img_arr = np.frombuffer(img_bytes, np.uint8)
img = cv2.imdecode(img_arr, cv2.IMREAD_COLOR)
cv2_imshow(img)

# %% [markdown]
# ## 7️⃣ Tracking de objetos por color (HSV)

# %%
uploaded = files.upload()
video_path = list(uploaded.keys())[0]

cap = cv2.VideoCapture(video_path)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # Detectar color verde
    lower = np.array([40, 50, 50])
    upper = np.array([80, 255, 255])

    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(frame, frame, mask=mask)

    cv2_imshow(result)
    break  # quitar para ver todo el video

cap.release()
